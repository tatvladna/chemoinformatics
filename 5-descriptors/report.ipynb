# %% [markdown]
# ----------------
#
# # Отчет по лабораторной работе: "Дескрпиторы"
#
# ---------

# %% [markdown]
# ## Дата выполнения лабораторной работы
#
# `04.01.2025`

# %% [markdown]
# ---
#
# ## Название лабораторной работы
#
# `"Дескрипторы"`

# %% [markdown]
# ---
#
# ## Цель лабораторной работы
#
# `Сравнение влияния нормализации и стандартизации на дескрипторы данных`

# %% [markdown]
# ----------------------
#
# ## Задачи лабораторной работы
#
# - Изучить способы извлечения дескрипторов из библиотеки RDkit.
# - Ознакомиться со способами масштабироваия дескрипторов.
# - Применить методы нормализации (Min-Max) и стандартизации (Z-score) к дескрипторам.

# %% [markdown]
# ----
#
# ## Материалы, использовавшиеся для выполнения лабораторной работы (программы, исходные файлы ?)
#
# 1. [Официальная документация RDKit](https://www.rdkit.org/docs/source/rdkit.Chem.html)
# 2. [Официальная документация scikit-learn](https://scikit-learn.org/1.5/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %% [markdown]
# ----
#
# ## Поэтапное изложение процедуры
#
# Сначала были извлечены основные, самые популярные и самые используемые физико-химические дескрипторы из библиотеки RDKit. Далее эти дескрипторы были стандартизированы  и нормализированы ручным способом и с помощью встроенных методов из библиотеки scikit-learn.

# %% [markdown]
# -----
#
# ## Результаты работы (+ таблицы, графики, иллюстрации?, если требуются)

# %% [markdown]
# ----
#
# ## Выводы
#
# В данной лабораторной работе были изучены основные виды дескрипторов в хемоинформатике. Если используемая выборка является генеральной, то оценка дисперсии через смещенную не будет отличаться от оценки дисперсии через несмещенную формулу. Но зачастую генеральная выборка неизвестна и для более точного результата нужно пользоваться несмещенной оценкой дисперсии и стандартного отклонения.
